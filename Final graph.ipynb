# %%
from sklearn.datasets import load_files       
from sklearn.model_selection import train_test_split
# from keras.utils import np_utils
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import normalize

# %%
size = np.array([700,300,80,60,20])

# %%
accuracy = np.array([86.4,86.1,86,85.4,85.3])
score = accuracy/size

# %%
plt.plot(size,score)
plt.title('Score v/s Size of Model')
plt.xlabel('Size of Model')
plt.ylabel('Score')
plt.savefig('Score vs Size of Model.png')
plt.show()

# %%
plt.plot(size,accuracy)
plt.title('Accuracy v/s Size of Model')
plt.xlabel('Size of Model')
plt.ylabel('Accuracy')
plt.savefig('Accuracy vs Size of Model.png')
plt.show()

# %%
plt.plot(accuracy, score)
plt.title('Score v/s Accuracy')
plt.xlabel('Accuracy')
plt.ylabel('Score')
plt.savefig('Score vs Accuracy.png')
plt.show()

# %%
norm_size = normalize(size[:,np.newaxis], axis=0).ravel()
norm_accuracy = normalize(accuracy[:,np.newaxis], axis=0).ravel()
# Out:
# /Users/300006798/anaconda2/envs/dog-project/lib/python3.5/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, _DataConversionWarning)

# %%
plt.plot(norm_size)
plt.plot(norm_accuracy)

# %%
norm_accuracy
# Out:
# array([ 0.45012566,  0.44856273,  0.44804175,  0.44491588,  0.4443949 ])
